# %% [markdown]
# # MATPLOTLIB
#
# **Matplotlib** is a library for creating statistical or animated static plots in Python. It allows us to customize practically any element of a data visualization.
#
# In **Matplotlib** all the graphical development will be done through the **Pyplot** interface.
#
# In **Pyplot** all the graphic representation is done sequentially, that is, a new function supposes an alteration in the current graph and so on.
#
# Like many python libraries, pyplot is commonly used under an alias **plt**, we'll start by importing the library.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We will make a very simple graph to start, paint the elements of a list

# %%
my_list = [1, 5, 10, 15, 20, 25, 30]

# %% [markdown]
# The first thing we will do to make a plot is to call the function <code>**plot**</code>

# %%
# [1, 5, 10, 15, 20, 25, 30] # Eje y
# [0, 1, 2,  3,  4,  5,  6]  # Eje x (índice)

# %%
plt.plot(my_list)

# %% [markdown]
# We see that we simply display each index value with its corresponding list value.
#
# We can add some style elements like labels to the *y* axis, and to the *x* axis. To do this, we add a new component with <code>**ylabel**</code> or <code>**xlabel**</code>

# %%
plt.xlabel("Índice de la lista")
plt.ylabel("Elementos de la lista")
# Out:
# Text(0, 0.5, 'Elementos de la lista')

# %% [markdown]
# As we can see, nothing from the previous list appears, so that pyplot takes into account all the elements that we are adding to a graph and shows them correctly on the screen, we have to define where our graph ends with the function <code>**show**</code>

# %%
plt.plot(my_list)

plt.xlabel("Índice de la lista")
plt.ylabel("Elementos de la lista")
# Out:
# Text(0, 0.5, 'Elementos de la lista')

# %%
plt.plot(my_list)

plt.xlabel("Índice de la lista")
plt.ylabel("Elementos de la lista")

plt.show()

# %% [markdown]
# Now that we know how to print something basic like a list against its own index, we are going to make a modification and instead of showing the index on the x-axis we will show another list with different values.

# %%
my_list_2 = [100, 10, 200, 2, 40.7, 800, 30]

# %%
my_list[0]
# Out:
# 1

# %%
my_list_2[0]
# Out:
# 100

# %%
plt.plot(my_list, my_list_2) # plot(x, y)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %% [markdown]
# In view of this new graph, it is important to highlight something:
# * The horizontal abscissa axis **x** takes the value of the first parameter (in its absence it will be the index of the list)
# * The vertical abscissa axis **y** takes the value of the second parameter.
#
# On some occasions, we may need wider or smaller axes for our graphs, for this we can make a new list containing 4 values:
# * Start of X axis
# * End of X axis
# * Start of Y axis
# * End of Y axis
#
# We will pass these values to the parameter <code>**axis**</code>

# %%
index_list = [-20, 50, -200, 1000]

plt.plot(my_list, my_list_2) # plot(x, y)
plt.axis(index_list)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %% [markdown]
# Finally, on our first graph, we can decide to change the color, this is done from the **plot** parameter, after the input arguments of the x and y axes, we can define the color through the <code>**color* parameter *</code>

# %%
plt.plot(my_list, my_list_2, color = "red" ) # plot(x, y)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %%
plt.plot(my_list, my_list_2, color = "green" ) # plot(x, y)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %%
plt.plot(my_list, my_list_2, color = "darkred" ) # plot(x, y)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %%
plt.plot(my_list, my_list_2, color = "g" ) # plot(x, y)

plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %% [markdown]
# We can find a list of colors that we can use in the following link: https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %% [markdown]
# Another function of interest is to add a title to a graph, we do this from <code>**title**</code>

# %%
# Listas a representar
plt.plot(my_list, my_list_2, color = "g" ) # plot(x, y)

# Elementos de texto
plt.title("Edad de una persona contra su nivel de ingresos")
plt.xlabel("Valores my_list X")
plt.ylabel("Valores my_list_2 Y")

plt.show()

# %% [markdown]
# In these first examples we have seen how to play with the width of the axes and display two lists. However, it is common for different variables to be superimposed on the same graph, the process is the same, that is, we have to add elements with plot.

# %%
import numpy as np

# %%
# https://numpy.org/doc/stable/reference/generated/numpy.linspace.html
arr = np.linspace(-2, 2, 200)

# %%
square = arr ** 2
cubo   = arr ** 3

# %%
plt.plot(arr)
plt.plot(square)
plt.plot(cubo)

plt.show()

# %% [markdown]
# When we add more than one variable to the graph, the color and width of the x and y axis are automatically defined. In these cases it is interesting to add a legend to our graph.
#
# To add a legend, we have to use the <code>**legend()**</code> function, but, in each plot element, we have to use the <code>**label**</code> parameter to add the text that will appear in the legend of our graph.

# %%
plt.plot(arr      , label = "Vector original")
plt.plot(square   , label = "Vector al cuadrado")
plt.plot(cubo     , label = "Vector al cubo")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plt.plot(arr      , label = "Vector original")
#       2 plt.plot(square   , label = "Vector al cuadrado")
#       3 plt.plot(cubo     , label = "Vector al cubo")
#
# NameError: name 'plt' is not defined

# %%
plt.plot(arr      , label = "Vector original")
plt.plot(square   , label = "Vector al cuadrado")
plt.plot(cubo     , label = "Vector al cubo")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend(loc="lower left")

plt.show()

# %%
plt.plot(arr   ,color = "gold"   , label = "Vector original")
plt.plot(square  ,color = "magenta" , label = "Vector al cuadrado")
plt.plot(cubo   ,color = "brown"  , label = "Vector al cubo")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend(loc="lower left")

plt.show()

# %% [markdown]
# ### Question
#
# What happens if the three arrays of the previous graph did not have the same length?

# %%
plt.plot(arr      , label = "Vector original")
plt.plot(square[:80]   , label = "Vector al cuadrado")
plt.plot(cubo[:150]     , label = "Vector al cubo")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend(loc="lower left")

plt.show()

# %% [markdown]
# Not only can we use lines as shapes to represent our graphs, but there are other types of elements that we can represent. A complete list of these elements can be consulted from the following link: https://matplotlib.org/3.1.1/api/markers_api.html

# %%
plt.plot(arr   ,color = "gold"   , label = "Vector original", marker = ".")
plt.plot(square  ,color = "magenta" , label = "Vector al cuadrado", marker = "^")
plt.plot(cubo   ,color = "brown"  , label = "Vector al cubo", marker = "s")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend(loc="lower left")

plt.show()

# %% [markdown]
# We show a clearer example.

# %%
aux = np.arange(10)

# %%
plt.plot(aux   ,color = "gold"   , label = "Vector original", marker = ".")
plt.plot(aux**2  ,color = "magenta" , label = "Vector al cuadrado", marker = "^")
plt.plot(aux**3   ,color = "brown"  , label = "Vector al cubo", marker = "s")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.legend(loc="lower left")

plt.show()

# %%
plt.plot(aux     , "--")
plt.plot(aux**2  , ".")
plt.plot(aux**3  , "^")

plt.title("Transformadas del array arr")
plt.xlabel("Eje | Longitud de los arrays")
plt.ylabel("Valores del array")

plt.show()

# %% [markdown]
# Through **Pyplot**, we can also add more than one visualization in the same graphic space, for this there is this important function <code>**subplot**</code>, it receives the following parameters:
# * Number of rows
# * Number of columns
# * Index (position)
#
# We will show an example of two graphs (so two rows, one column and even two graphs)

# %%
def balance(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

# %%
my_array_uno = np.arange(0, 5.0, 0.1)
my_array_dos = np.arange(0, 5.0, 0.02)

my_array_dos
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#        0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#        0.88, 0.9 , 0.92, 0.94, 0.96, 0.98, 1.  , 1.02, 1.04, 1.06, 1.08,
#        1.1 , 1.12, 1.14, 1.16, 1.18, 1.2 , 1.22, 1.24, 1.26, 1.28, 1.3 ,
#        1.32, 1.34, 1.36, 1.38, 1.4 , 1.42, 1.44, 1.46, 1.48, 1.5 , 1.52,
#        1.54, 1.56, 1.58, 1.6 , 1.62, 1.64, 1.66, 1.68, 1.7 , 1.72, 1.74,
#        1.76, 1.78, 1.8 , 1.82, 1.84, 1.86, 1.88, 1.9 , 1.92, 1.94, 1.96,
#        1.98, 2.  , 2.02, 2.04, 2.06, 2.08, 2.1 , 2.12, 2.14, 2.16, 2.18,
#        2.2 , 2.22, 2.24, 2.26, 2.28, 2.3 , 2.32, 2.34, 2.36, 2.38, 2.4 ,
#        2.42, 2.44, 2.46, 2.48, 2.5 , 2.52, 2.54, 2.56, 2.58, 2.6 , 2.62,
#        2.64, 2.66, 2.68, 2.7 , 2.72, 2.74, 2.76, 2.78, 2.8 , 2.82, 2.84,
# ...

# %% [markdown]
# Las posiciones para subplot, siempre son 3 números
# * **1 Filas**
# * **2 Columnas**
# * 3 Posición
#
# `plt.subplot(323)`

# %%
plt.plot(my_array_uno, balance(my_array_uno), "bo")
plt.plot(my_array_dos, balance(my_array_dos), "k")
plt.show()

# %%
balance(my_array_uno)
# Out:
# array([ 1.        ,  0.73202885,  0.25300172, -0.22892542, -0.54230031,
#        -0.60653066, -0.44399794, -0.1534533 ,  0.13885029,  0.32892176,
#         0.36787944,  0.26929836,  0.09307413, -0.08421696, -0.19950113,
#        -0.22313016, -0.16333771, -0.05645231,  0.05108017,  0.12100355,
#         0.13533528,  0.09906933,  0.03424006, -0.03098169, -0.07339237,
#        -0.082085  , -0.06008859, -0.02076765,  0.01879134,  0.04451472,
#         0.04978707,  0.03644557,  0.01259621, -0.01139753, -0.02699954,
#        -0.03019738, -0.02210536, -0.00763999,  0.00691295,  0.01637605,
#         0.01831564,  0.01340758,  0.00463389, -0.00419292, -0.00993258,
#        -0.011109  , -0.00813211, -0.0028106 ,  0.00254313,  0.00602441])

# %%
# Fila 1 columa 1, gráfica 1
plt.subplot(211)
plt.plot(my_array_uno, balance(my_array_uno), "bo")
plt.plot(my_array_dos, balance(my_array_dos), "k")

# Fila 2 columa 1, gráfica 2
plt.subplot(212)
plt.plot(my_array_dos, np.cos(2*np.pi*my_array_dos), "r--")

plt.show()

# %%
# Si alteramos las posiciones

plt.subplot(221)
plt.plot(my_array_uno, balance(my_array_uno), "bo")
plt.plot(my_array_dos, balance(my_array_dos), "k")

plt.subplot(224)
plt.plot(my_array_dos, np.cos(2*np.pi*my_array_dos), "r--")

plt.show()

# %%
# Si alteramos las posiciones

plt.subplot(221)
plt.plot(my_array_uno, balance(my_array_uno), "bo")
plt.plot(my_array_dos, balance(my_array_dos), "k")

# No le llega nada visual
plt.subplot(222)

plt.subplot(224)
plt.plot(my_array_dos, np.cos(2*np.pi*my_array_dos), "r--")

plt.show()

# %% [markdown]
# **Modify pyplot margins**

# %%
plt.rcParams['figure.figsize'] = [10, 5]

# %%
# Si alteramos las posiciones

plt.subplot(221)
plt.plot(my_array_uno, balance(my_array_uno), "bo")
plt.plot(my_array_dos, balance(my_array_dos), "k")

# No le llega nada visual
plt.subplot(222)

plt.subplot(224)
plt.plot(my_array_dos, np.cos(2*np.pi*my_array_dos), "r--")

plt.show()

# %% [markdown]
# Before we go over different types of charts, we'll show how to add text inside a visualization.
#
# The function <code>**text**</code> followed by the x and y position where the text will go, will allow us to add text inside a visualization. We will take the graph above as an example.

# %%
plt.plot(arr, color = "r", label = "Vector original")
plt.plot(arr**2, color = "g", label = "Vector al cuadrado")
plt.plot(arr**3, color = "b", label = "Vector al cubo")

plt.legend()
plt.text(25, 2.5, "Transformación al cuadrado")
plt.text(25, -5, "Transformación al cubo")
plt.text(0, -0.5, "Transformación al cuadrado")
plt.show()

# %% [markdown]
# Now, we will show some types of graphs other than the line graph.
#
# ## Histogram.
#
# To generate a histogram we use the `plt.hist()` function, as parameters we will pass the vector that we are going to represent and the parameter that determines the number of bars that will be represented in the histogram **bins**

# %%
plt.hist(balance(my_array_dos))
plt.show()

# %%
plt.hist(np.random.randint(10, 1000, 1000))
plt.show()

# %%
plt.hist(np.random.randint(10, 1000, 1000), bins=50)
plt.show()

# %%
plt.hist(np.random.randint(10, 1000, 1000), bins=100)
plt.show()

# %% [markdown]
# ## BAR CHART
#
# To generate a bar chart we will use the `plt.bar` function which will receive two parameters, the vector to represent and its height. This type of graph is advisable to use when we have a categorical variable and a numerical one.

# %%
x = np.arange(3)

# 0, 1, 2

plt.bar(x, height=[1, 2, 3])
plt.show()

# %%
x = np.arange(3)

# 0, 1, 2

plt.bar(x, height=[1, 2, 3])
plt.xticks(x, ["Producto A", "Producto B", "Producto C"])
plt.show()

# %% [markdown]
# Using another example, we are going to generate a series of dates, 12 days and 2 arrays to simulate the air quality indices of two cities. In this case we will see how the **plot** function works from a dataframe, which internally also incorporates pyplot

# %%
import pandas as pd

# %%
fechas = pd.date_range("20220101", periods=12)

fechas
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
vector = np.random.randint(10, 50, 24).reshape(12, 2)
vector
# Out:
# array([[14, 19],
#        [35, 45],
#        [12, 32],
#        [36, 40],
#        [39, 43],
#        [47, 10],
#        [43, 10],
#        [26, 44],
#        [24, 28],
#        [43, 12],
#        [48, 48],
#        [40, 29]])

# %%
calidad_aire = pd.DataFrame(vector, index=fechas, columns=["AQI MADRID", "AQI BARCELONA"])

calidad_aire
# Out:
#             AQI MADRID  AQI BARCELONA
# 2022-01-01          14             19
# 2022-01-02          35             45
# 2022-01-03          12             32
# 2022-01-04          36             40
# 2022-01-05          39             43
# 2022-01-06          47             10
# 2022-01-07          43             10
# 2022-01-08          26             44
# 2022-01-09          24             28
# 2022-01-10          43             12
# 2022-01-11          48             48
# 2022-01-12          40             29

# %% [markdown]
# Two bar charts can also be superimposed

# %%
calidad_aire.plot(kind="barh", title="Calidad del aire")
# Out:
# <AxesSubplot:title={'center':'Calidad del aire'}>

# %%
calidad_aire.plot(kind="bar", title="Calidad del aire")
# Out:
# <AxesSubplot:title={'center':'Calidad del aire'}>

# %%
calidad_aire.plot(kind="bar", title="Calidad del aire", subplots=True)
plt.show()

# %%
calidad_aire.plot(kind="barh", title="Calidad del aire", subplots=True)
plt.show()

# %%
vector = np.random.randint(10, 50, 36).reshape(12, 3)
vector

calidad_aire = pd.DataFrame(vector, index=fechas, columns=["AQI MADRID", "AQI BARCELONA", "AQUI ASTURIAS"])

calidad_aire
# Out:
#             AQI MADRID  AQI BARCELONA  AQUI ASTURIAS
# 2022-01-01          12             11             41
# 2022-01-02          36             25             19
# 2022-01-03          12             46             38
# 2022-01-04          36             10             30
# 2022-01-05          25             35             24
# 2022-01-06          22             32             49
# 2022-01-07          31             44             42
# 2022-01-08          49             16             41
# 2022-01-09          43             28             45
# 2022-01-10          44             33             42
# 2022-01-11          48             16             21
# 2022-01-12          40             15             49

# %%
calidad_aire.plot(kind="bar", title="Calidad del aire")
# Out:
# <AxesSubplot:title={'center':'Calidad del aire'}>

# %%
calidad_aire.plot(kind="barh", title="Calidad del aire", subplots=True)
plt.show()

# %%
calidad_aire.plot(kind="barh", title="Calidad del aire", subplots=True, figsize = (10, 10))
plt.show()

# %%
vector = np.random.randint(10, 50, 24).reshape(12, 2)

calidad_aire = pd.DataFrame(vector, index=fechas, columns=["AQI MADRID", "AQI BARCELONA"])

calidad_aire.plot(kind="line", title="Calidad del aire")
plt.show()

# %%
calidad_aire.plot(kind="box", title="Calidad del aire")
plt.show()

# %%
calidad_aire.loc["2022-01-05"]["AQI MADRID"] = 100

# %%
calidad_aire
# Out:
#             AQI MADRID  AQI BARCELONA
# 2022-01-01          15             35
# 2022-01-02          19             24
# 2022-01-03          44             40
# 2022-01-04          46             14
# 2022-01-05         100             27
# 2022-01-06          23             17
# 2022-01-07          12             48
# 2022-01-08          26             34
# 2022-01-09          33             22
# 2022-01-10          31             37
# 2022-01-11          47             24
# 2022-01-12          48             31

# %%
calidad_aire.plot(kind="box", title="Calidad del aire")
plt.show()

# %%
calidad_aire.plot(kind="line", title="Calidad del aire")
plt.show()

# %%
temp_max = [20, 25, 22, 18]
temp_min = [10, 7, 14, 16]
n_barras = range(0,len(temp_max))

# %%
max_ = plt.bar(n_barras, temp_max, color = "darkred", label = "Temperatura máxima")
min_ = plt.bar(n_barras, temp_min, color = "lightgreen", label = "Temperatura mínima")

plt.xlabel("Días")
plt.ylabel("Temperatura")
plt.legend()

plt.xticks(n_barras, ("29/11/2022", "30/11/2022", "01/12/2022", "02/12/2022"))

plt.show()

# %%
temp_max = [20, 25, 22, 18]
temp_min = [10, 7, 14, 20]
n_barras = range(0,len(temp_max))

max_ = plt.bar(n_barras, temp_max, color = "darkred", label = "Temperatura máxima")
min_ = plt.bar(n_barras, temp_min, color = "lightgreen", label = "Temperatura mínima")

plt.xlabel("Días")
plt.ylabel("Temperatura")
plt.legend()

plt.xticks(n_barras, ("29/11/2022", "30/11/2022", "01/12/2022", "02/12/2022"))

plt.show()

# %% [markdown]
# ## Pie Chart

# %%
politics = ("PSOE", "PP", "VOX", "PODEMOS", "ERC", "CS")
votos    = (40, 25, 10, 10, 8, 7)

# %%
plt.pie(votos, labels=politics)
plt.show()

# %%
plt.pie(votos, labels=politics, colors = ("r", "b", "g", "purple", "yellow", "orange"))
plt.show()

# %%
plt.pie(votos, labels=politics, colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=90)
plt.show()

# %%
plt.pie(votos, labels=politics, colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=120)
plt.show()

# %%
plt.pie(votos, labels=politics, colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=120, shadow=True)
plt.show()

# %%
plt.pie(votos, 
        labels=politics, 
        
        colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=120, 
        shadow=True, autopct="%1.1f%%"
   )
plt.show()

# %%
plt.pie(votos, 
        labels=politics, 
        
        colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=120, 
        shadow=True, autopct="%1.3f%%"
   )
plt.show()

# %%
plt.pie(votos, 
        labels=politics, 
        
        colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=90, 
        shadow=True, 
        autopct="%1.3f%%",
        explode=(0.2, 0, 0, 0, 0, 0)
   )
plt.show()

# %%
# ("PSOE", "PP", "VOX", "PODEMOS", "ERC", "CS")

plt.pie(votos, 
        labels=politics, 
        
        colors = ("r", "b", "g", "purple", "yellow", "orange"), 
        startangle=90, 
        shadow=True, 
        autopct="%1.3f%%",
        explode=(0.3, 0, 0, 0.3, 0.3, 0), 
        counterclock=False
   )
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
vector_uno = np.random.randint(0, 50, 100)
vector_dos = np.random.randint(0, 50, 100)
index = np.arange(100)

# %%
plt.scatter(index, vector_uno, color="b")
plt.scatter(index, vector_dos, color="r")
plt.show()

# %%
plt.scatter(range(0, len(calidad_aire)), calidad_aire["AQI MADRID"], color="b")
plt.scatter(range(0, len(calidad_aire)), calidad_aire["AQI BARCELONA"], color="r")
plt.show()

# %%
calidad_aire.plot(kind="scatter", x = "AQI BARCELONA", y ="AQI MADRID")
# Out:
# <AxesSubplot:xlabel='AQI BARCELONA', ylabel='AQI MADRID'>

# %% [markdown]
# ## More advanced Plots

# %% [markdown]
# How to add an arrow

# %%
plt.plot(arr, color = "r", label = "Vector original")
plt.plot(arr**2, color = "g", label = "Vector al cuadrado")
plt.plot(arr**3, color = "b", label = "Vector al cubo")

plt.legend()
plt.text(25, 2.5, "Transformación al cuadrado")
plt.text(25, -5, "Transformación al cubo")
plt.text(0, -0.5, "Transformación al cuadrado")

plt.annotate("Punto de corte", xy = (125, 1), xytext=(150, 6), 
             arrowprops = dict(facecolor="black", shrink=0.05))
plt.show()

# %%
calidad_aire.loc["2022-01-05"]["AQI MADRID"] = 100

# %%
calidad_aire
# Out:
#             AQI MADRID  AQI BARCELONA  AQUI ASTURIAS
# 2022-01-01          12             11             41
# 2022-01-02          36             25             19
# 2022-01-03          12             46             38
# 2022-01-04          36             10             30
# 2022-01-05         100             35             24
# 2022-01-06          22             32             49
# 2022-01-07          31             44             42
# 2022-01-08          49             16             41
# 2022-01-09          43             28             45
# 2022-01-10          44             33             42
# 2022-01-11          48             16             21
# 2022-01-12          40             15             49

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI MADRID"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI BARCELONA"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQUI ASTURIAS"])
plt.annotate("Outlier !!!", xy = (4, 100), xytext=(5, 120), 
             arrowprops = dict(facecolor="black", shrink=0.05))
plt.show()

# %%
calidad_aire.describe()
# Out:
#        AQI MADRID  AQI BARCELONA  AQUI ASTURIAS
# count   12.000000      12.000000      12.000000
# mean    39.416667      25.916667      36.750000
# std     22.904777      12.420352      10.584079
# min     12.000000      10.000000      19.000000
# 25%     28.750000      15.750000      28.500000
# 50%     38.000000      26.500000      41.000000
# 75%     45.000000      33.500000      42.750000
# max    100.000000      46.000000      49.000000

# %% [markdown]
# How to add vertical or horizontal lines

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI MADRID"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI BARCELONA"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQUI ASTURIAS"])
plt.annotate("Outlier !!!", xy = (4, 100), xytext=(5, 90), 
             arrowprops = dict(facecolor="black", shrink=0.05))
plt.axhline(y=calidad_aire["AQI MADRID"].mean(), color="r")

plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI MADRID"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQI BARCELONA"])
ax.plot(range(0, len(calidad_aire)), calidad_aire["AQUI ASTURIAS"])
plt.annotate("Outlier !!!", xy = (4, 100), xytext=(5, 90), 
             arrowprops = dict(facecolor="black", shrink=0.05))
plt.axvline(x=4, color="r")

plt.show()

# %%
plt.scatter(index, vector_uno, color="b", linewidths = 5)
plt.scatter(index, vector_dos, color="r")
plt.show()

# %% [markdown]
# Now, represent all columns with different formats

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.plot(indices, calidad_aire["AQI MADRID"]   , color="red"    ,ls = "-.")
ax.plot(indices, calidad_aire["AQI BARCELONA"], color="orange" ,lw = 10)
ax.plot(indices, calidad_aire["AQUI ASTURIAS"], color="purple" ,lw = 1, marker='o')

plt.show()

# %% [markdown]
# Using subplots functions now, generate the same line charts but in subplot mode, accesing to their index

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(3,1, figsize=(15, 8))

ax[0].plot(indices, calidad_aire["AQI MADRID"]   , color="red"    ,ls = "-."         )
ax[1].plot(indices, calidad_aire["AQI BARCELONA"], color="orange" ,lw = 10           )
ax[2].plot(indices, calidad_aire["AQUI ASTURIAS"], color="purple" ,lw = 1, marker='o')

plt.show()

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(3,1, figsize=(15, 8))

# Cada visualización por índice
ax[0].plot(indices, calidad_aire["AQI MADRID"]   , color="red"    ,ls = "-."         , label = "AQI MADRID")
ax[1].plot(indices, calidad_aire["AQI BARCELONA"], color="orange" ,lw = 10           , label = "AQI BARCELONA")
ax[2].plot(indices, calidad_aire["AQUI ASTURIAS"], color="purple" ,lw = 1, marker='o', label = "AQUI ASTURIAS")

# Cada leyenda por índice
ax[0].legend()
ax[1].legend()
ax[2].legend()

plt.show()

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(3,1, figsize=(15, 8))

# Cada visualización por índice
ax[0].plot(indices, calidad_aire["AQI MADRID"]   , color="red"    ,ls = "-."         , label = "AQI MADRID")
ax[1].plot(indices, calidad_aire["AQI BARCELONA"], color="orange" ,lw = 10           , label = "AQI BARCELONA")
ax[2].plot(indices, calidad_aire["AQUI ASTURIAS"], color="purple" ,lw = 1, marker='o', label = "AQUI ASTURIAS")

# Cada leyenda por índice
# Localización de la leyenda https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.legend.html
ax[0].legend(loc=4)
ax[1].legend(loc=6)
ax[2].legend(loc=2)

plt.show()

# %% [markdown]
# Adding data labels to barcharts

# %%
temp_max = [20, 25, 22, 18]
temp_min = [10, 7, 14, 14]
n_barras = range(0,len(temp_max))

# %%
fig, ax = plt.subplots(1,1, figsize = (15, 8))

ax.bar(n_barras, temp_max, color = "tomato", label = "Temperatura máxima")
# Tenemos que recorrer posiciones de índice
for max_value in range(0, len(temp_max)):
    ax.text(max_value, temp_max[max_value]+0.5, temp_max[max_value], horizontalalignment = "center")

ax.bar(n_barras, temp_min, color = "lightgreen", label = "Temperatura mínima")
for min_value in range(0, len(temp_min)):
    ax.text(min_value, temp_min[min_value] +0.5, temp_min[min_value], horizontalalignment = "center")

plt.xlabel("Días")
plt.ylabel("Temperatura")
plt.title("Temperatura por días")
plt.legend()

plt.xticks(n_barras, ("29/11/2022", "30/11/2022", "01/12/2022", "02/12/2022"))

plt.show()

# %%
calidad_aire.shape[0]
# Out:
# 12

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(3,1, figsize=(15, 15))

# Cada visualización por índice
ax[0].bar(indices, calidad_aire["AQI MADRID"]   , color="red"    , label = "AQI MADRID")

for value_madrid in range(0, len(calidad_aire)):
    ax[0].text(value_madrid, 
               calidad_aire["AQI MADRID"][value_madrid] +1, 
               calidad_aire["AQI MADRID"][value_madrid], 
               horizontalalignment = "center")

ax[1].bar(indices, calidad_aire["AQI BARCELONA"], color="orange" , label = "AQI BARCELONA")

for value_barcelona in range(0, len(calidad_aire)):
    ax[1].text(value_barcelona, 
               calidad_aire["AQI BARCELONA"][value_barcelona] +1, 
               calidad_aire["AQI BARCELONA"][value_barcelona], 
               horizontalalignment = "center")

ax[2].bar(indices, calidad_aire["AQUI ASTURIAS"], color="purple" , label = "AQUI ASTURIAS")

for value_asturias in range(0, len(calidad_aire)):
    ax[2].text(value_asturias, 
               calidad_aire["AQUI ASTURIAS"][value_asturias] +1, 
               calidad_aire["AQUI ASTURIAS"][value_asturias], 
               horizontalalignment = "center")
    
# Cada leyenda por índice
ax[0].legend()
ax[1].legend()
ax[2].legend()

plt.show()

# %%
indices = range(0, len(calidad_aire))

fig, ax = plt.subplots(3,1, figsize=(15, 15))

# Cada visualización por índice
ax[0].bar(indices, calidad_aire["AQI MADRID"]   , color="red"    , label = "AQI MADRID")

for value_madrid in range(0, len(calidad_aire)):
    ax[0].text(value_madrid, 
               calidad_aire["AQI MADRID"][value_madrid] +1, 
               calidad_aire["AQI MADRID"][value_madrid], 
               horizontalalignment = "center")

ax[1].bar(indices, calidad_aire["AQI BARCELONA"], color="orange" , label = "AQI BARCELONA")

for value_barcelona in range(0, len(calidad_aire)):
    ax[1].text(value_barcelona, 
               calidad_aire["AQI BARCELONA"][value_barcelona] +1, 
               calidad_aire["AQI BARCELONA"][value_barcelona], 
               horizontalalignment = "center")

ax[2].bar(indices, calidad_aire["AQUI ASTURIAS"], 
          color="purple" , label = "AQUI ASTURIAS")

ax[2].bar(indices, calidad_aire["AQI BARCELONA"], 
          color="orange" , label = "AQI BARCELONA", 
          bottom = calidad_aire["AQUI ASTURIAS"])

# Frecuencia acumulada
for value_asturias in range(0, len(calidad_aire)):
    ax[2].text(value_asturias, 
               calidad_aire["AQUI ASTURIAS"][value_asturias] + calidad_aire["AQI BARCELONA"][value_asturias] +1, 
               calidad_aire["AQUI ASTURIAS"][value_asturias] + calidad_aire["AQI BARCELONA"][value_asturias], 
               horizontalalignment = "center")
    
# Cada leyenda por índice
ax[0].legend()
ax[1].legend()
ax[2].legend()

plt.show()

# %%
df = pd.DataFrame({
    "Team": ["FC BARCELONA", "REAL MADRID", 
             "ATLÉTICO MADRID", "ATHLETIC", 
             "BETIS"],
    "Points": (22, 22, 19, 17, 16),
    "% Victories" : [90, 90, 70, 60, 50]
})

# %%
df
# Out:
#               Team  Points  % Victories
# 0     FC BARCELONA      22           90
# 1      REAL MADRID      22           90
# 2  ATLÉTICO MADRID      19           70
# 3         ATHLETIC      17           60
# 4            BETIS      16           50

# %%
plt.plot(range(len(df)), df["% Victories"])

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.bar(df.Team, df.Points, color = "tomato")

for punto in range(len(df)):
    ax.text(df["Team"][punto], df["Points"][punto] +0.5, df["Points"][punto], horizontalalignment="center")
    
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))

ax.bar(df.Team, df.Points, color = "tomato")

for punto in range(len(df)):
    ax.text(df["Team"][punto], df["Points"][punto] +0.5, df["Points"][punto], horizontalalignment="center")
    
ax_dos = ax.twinx()

ax_dos.plot(df.Team, df["% Victories"], lw=5)
for victoria in range(len(df)):
    ax_dos.text(df["Team"][victoria], 
                df["% Victories"][victoria]-1.5, 
                df["% Victories"][victoria], 
                horizontalalignment="center")

ax_dos.plot()
    
plt.show()
