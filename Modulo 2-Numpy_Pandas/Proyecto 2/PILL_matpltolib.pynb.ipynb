# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df.index = ["enero" , "febrero", "marzo", "abril" ,"mayo", "junio", "julio", "agosto", "septiembre", "octubre", "noviembre", "diciembre"]
df
# Out:
#             month_number  facecream  facewash  toothpaste  bathingsoap  \
# enero                  1       2500      1500        5200         9200
# febrero                2       2630      1200        5100         6100
# marzo                  3       2140      1340        4550         9550
# abril                  4       3400      1130        5870         8870
# mayo                   5       3600      1740        4560         7760
# junio                  6       2760      1555        4890         7490
# julio                  7       2980      1120        4780         8980
# agosto                 8       3700      1400        5860         9960
# septiembre             9       3540      1780        6100         8100
# octubre               10       1990      1890        8300        10300
# noviembre             11       2340      2100        7300        13300
# diciembre             12       2900      1760        7400        14400
#
# ...

# %% [markdown]
# 1. Lea el beneficio total de todos los meses y muéstrelo usando un gráfico de líneas

# %%
total = df["total_profit"].copy()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(total)
plt.show()

# %%
total
# Out:
# enero         211000
# febrero       183300
# marzo         224700
# abril         222700
# mayo          209600
# junio         201400
# julio         295500
# agosto        361400
# septiembre    234000
# octubre       266700
# noviembre     412800
# diciembre     300200
# Name: total_profit, dtype: int64

# %% [markdown]
# 2. Obtenga el beneficio total de todos los meses y muestre el diagrama de líneas con las siguientes propiedades de estilo:
#
# a. Estilo de línea punteado y color de línea debe ser rojo
# b. Mostrar leyenda en la ubicación inferior derecha.
# C. Nombre de etiqueta X = Número de mes
#
# d. Nombre de etiqueta Y = número de unidades vendidas
# mi. Añade un marcador de círculo.
# F. Color del marcador de línea como se lee
# gramo. El ancho de línea debe ser 3

# %%
total
# Out:
# enero         211000
# febrero       183300
# marzo         224700
# abril         222700
# mayo          209600
# junio         201400
# julio         295500
# agosto        361400
# septiembre    234000
# octubre       266700
# noviembre     412800
# diciembre     300200
# Name: total_profit, dtype: int64

# %% [markdown]
#     PUNTO A

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(total,"r--", label = "total")
plt.show()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26288\3810725992.py in <module>
#       1 plt.rcParams['figure.figsize'] = [20, 15]
# ----> 2 plt.plot(total, color = "r--", label = "total")
#       3 plt.show()
#       4 plt.legend()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
